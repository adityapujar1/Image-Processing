# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# A = plt.imread('images/lena_color.bmp')
# # print(A)
# type(A)

B = Image.open('images/profile.jpg')
B.show()
smaller_img = B.resize((150,150))
smaller_img.show()
print(smaller_img)
# smaller_img.shape

print(np.shape(A))
print(type(A))
print(A.dtype)
plt.imshow(A)
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x1A7D6EA80C8>
# (512, 512, 3)
# <class 'numpy.ndarray'>
# uint8
